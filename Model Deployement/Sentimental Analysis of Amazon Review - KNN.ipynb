# %% [markdown]
# # Text Sentiment Analysis Using Amazon Review Data

# %% [markdown]
# Predicting a review's numeric rating based on the textual review is a quintessential multiclass text classification problem and an interesting research topic in natural language processing. New advances in NLP including the development of Glove, and Word2Vec, have increased the range of approaches available to address this question, and insights gained on this problem can generalize across sentiment analysis and NLP multiclass classification problems in general. We leveraged the extensive corpus of multi-class labeled Amazon data to apply sentiment analysis.
#
# ```Objective:``` Given a text book review, predict one of the three ```(positive, neutral, negative)``` sentiment classes.

# %% [markdown]
# ### Importing the required libraries!!

# %%
# importing the libraries related to the data manipulation.
import numpy as np
import pandas as pd
import string

# importing the libraries related to the data_visualization.
import seaborn as sns
import matplotlib.pyplot as plt

# TextBlob is a Python library for processing textual data.
from textblob import TextBlob

# To avoid warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading the Book Review Dataset

# %%
# datapath = E:\DOWNLOADS\book_review.csv
Book_review = pd.read_csv(r'E:\DOWNLOADS\book_review.csv')
Book_review
# Out:
#                                                unique_id        asin  \
# 0      1884956068:a_mainstay_reference_for_spanish-sp...  1884956068
# 1      0679728740:you_want_the_necrophiliac_to_escape...  0679728740
# 2          0679728740:low_brow_and_juvenile:bruce_miller  0679728740
# 3      0679728740:mccarthy,_a_brave_writer_with_an_in...  0679728740
# 4      0679728740:sevierville_in_child_of_god:alex_jo...  0679728740
# ...                                                  ...         ...
# 41995                  0972894403:that's_it!:terrie_cash  0972894403
# 41996  0972894403:open_your_heart,_open_your_mind:hel...  0972894403
# 41997      0972894403:living_god's_will:patricia_newsome  0972894403
# 41998     0972894403:it_is_a_blessing:michael_abney,_sr.  0972894403
# 41999               0830833900:called_to_monday:r._eberz  0830833900
#
#                                             product_name product_type  \
# 0      Manual pedi�trico para los due�os del nuevo be...        books
# 1                   Child of God: Books: Cormac Mccarthy        books
# 2                   Child of God: Books: Cormac Mccarthy        books
# 3                   Child of God: Books: Cormac Mccarthy        books
# 4                   Child of God: Books: Cormac Mccarthy        books
# ...                                                  ...          ...
# 41995  Open Your Mind, Open Your Heart: Books: W. Mar...        books
# 41996  Open Your Mind, Open Your Heart: Books: W. Mar...        books
# 41997  Open Your Mind, Open Your Heart: Books: W. Mar...        books
# 41998  Open Your Mind, Open Your Heart: Books: W. Mar...        books
# 41999  Loving Monday: Succeeding in Business Without ...        books
#
#         helpful  rating                                              title  \
# 0        7 of 8     5.0  A mainstay reference for Spanish-speaking home...
# 1        0 of 1     5.0               You want the necrophiliac to escape?
# 2        2 of 5     2.0                              Low brow and juvenile
# 3        4 of 5     5.0  McCarthy, a brave writer with an incredible co...
# 4      11 of 14     4.0                        SEVIERVILLE in Child of God
# ...         ...     ...                                                ...
# 41995       NaN     5.0                                         That's it!
# 41996       NaN     5.0                    Open Your Heart, Open Your Mind
# 41997    1 of 1     5.0                                  Living God's Will
# 41998       NaN     5.0                                   It is a Blessing
# 41999    2 of 2     4.0                                   Called to Monday
#
#                      date                              reviewer  \
# 0           April 6, 2000                   Midwest Book Review
# 1        October 20, 2006                         Brian Asquith
# 2      September 26, 2006                          Bruce Miller
# 3           July 24, 2005  Christopher Davis "Christopher E.D."
# 4       November 20, 2002                          Alex Johnson
# ...                   ...                                   ...
# 41995        May 10, 2004                           Terrie Cash
# 41996    January 13, 2004                       helen bellanger
# 41997     January 8, 2004                      Patricia Newsome
# 41998     January 7, 2004                    Michael Abney, Sr.
# 41999   November 20, 2005                              R. Eberz
#
#                     reviewer_location  \
# 0                      Oregon, WI USA
# 1                                 NaN
# 2      Shippensburg, PA United States
# 3                       Cleveland, MS
# 4              Sevierville, Tennessee
# ...                               ...
# 41995                             USA
# 41996           apo, ap United States
# 41997                             USA
# 41998                             NaN
# 41999                    Beijing, PRC
#
#                                              review_text
# 0      This all-Spanish handbook for parents with new...
# 1      McCarthy's writing and portrayal of Lester Bal...
# 2      Do you giggle uncontrollably when poking corps...
# 3      I was initiated into the world of Cormac McCar...
# 4      I cannot speak to the literary points in the n...
# ...                                                  ...
# 41995  In reading this book, I traveled on a wonderfu...
# 41996  This wonderful book touches the inner soul.You...
# 41997  I am a 45 year old woman who has been on a que...
# 41998  It is written that you should hide the Word of...
# 41999  John Beckett has the feel of an average guy th...
#
# [42000 rows x 11 columns]

# %%
# shape of the actual dataframe
Book_review.shape
# Out:
# (42000, 11)

# %% [markdown]
# It has ```42000 rows and 11 columns```

# %%
# display the names of various columns present in the dataframe
Book_review.columns
# Out:
# Index(['unique_id', 'asin', 'product_name', 'product_type', 'helpful',
#        'rating', 'title', 'date', 'reviewer', 'reviewer_location',
#        'review_text'],
#       dtype='object')

# %%
# Find the information about the given dataFrame including the index dtype and column dtypes, non-null values and memory usage.
Book_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42000 entries, 0 to 41999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   unique_id          42000 non-null  object
#  1   asin               42000 non-null  object
#  2   product_name       42000 non-null  object
#  3   product_type       42000 non-null  object
#  4   helpful            34398 non-null  object
#  5   rating             42000 non-null  float64
#  6   title              41993 non-null  object
#  7   date               41993 non-null  object
#  8   reviewer           42000 non-null  object
#  9   reviewer_location  36876 non-null  object
#  10  review_text        42000 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 3.5+ MB

# %%
# Finding the total number of null values, if present
Book_review.isnull().sum()
# Out:
# unique_id               0
# asin                    0
# product_name            0
# product_type            0
# helpful              7602
# rating                  0
# title                   7
# date                    7
# reviewer                0
# reviewer_location    5124
# review_text             0
# dtype: int64

# %% [markdown]
# #### ```Considering only the "review_text" feature of the dataframe for our further analysis:```

# %%
pd.options.mode.chained_assignment = None
df = Book_review[["review_text"]]
df["review_text"] = df["review_text"].astype(str)
df.head()
# Out:
#                                          review_text
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...

# %%
# shape of the review data
df.shape
# Out:
# (42000, 1)

# %% [markdown]
# ### 1. Lowercasing the text of review_text:

# %%
df["lowercase_text"] = df["review_text"].str.lower()
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                       lowercase_text
# 0  this all-spanish handbook for parents with new...
# 1  mccarthy's writing and portrayal of lester bal...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...

# %% [markdown]
# ### 2. Removal of punctuations present in the text:

# %%
Punctuation_remove = string.punctuation
def remove_punctuation(lowercase_text):
    """custom function to remove the punctuation"""
    return lowercase_text.translate(str.maketrans('', '', Punctuation_remove))

df["NoPunctuations_text"] = df["lowercase_text"].apply(lambda lowercase_text: remove_punctuation(lowercase_text))
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                       lowercase_text  \
# 0  this all-spanish handbook for parents with new...
# 1  mccarthy's writing and portrayal of lester bal...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...
#
#                                  NoPunctuations_text
# 0  this allspanish handbook for parents with new ...
# 1  mccarthys writing and portrayal of lester ball...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...

# %% [markdown]
# ### 3. Removal of stopwords:

# %%
# importing the NLP library
import nltk
from nltk.corpus import stopwords
stopwords
# Out:
# <WordListCorpusReader in 'C:\\Users\\SAMARTH P SHET\\AppData\\Roaming\\nltk_data\\corpora\\stopwords'>

# %%
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to C:\Users\SAMARTH P
# [nltk_data]     SHET\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in stopwords])

df["Nostopwords_text"] = df["NoPunctuations_text"].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                       lowercase_text  \
# 0  this all-spanish handbook for parents with new...
# 1  mccarthy's writing and portrayal of lester bal...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...
#
#                                  NoPunctuations_text  \
# 0  this allspanish handbook for parents with new ...
# 1  mccarthys writing and portrayal of lester ball...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...
#
#                                     Nostopwords_text
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...

# %% [markdown]
# ### 4. Removal of Frequent words:

# %%
from collections import Counter
cnt = Counter()
for text in df["Nostopwords_text"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)
# Out:
# [('book', 79443),
#  ('read', 28623),
#  ('one', 27132),
#  ('like', 16226),
#  ('would', 15183),
#  ('time', 13181),
#  ('great', 12677),
#  ('story', 12663),
#  ('good', 12635),
#  ('books', 12467)]

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
def remove_freqwords(text):
    """custom function to remove the frequent words"""
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["NoFreqwords_text"] = df["Nostopwords_text"].apply(lambda text: remove_freqwords(text))
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                       lowercase_text  \
# 0  this all-spanish handbook for parents with new...
# 1  mccarthy's writing and portrayal of lester bal...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...
#
#                                  NoPunctuations_text  \
# 0  this allspanish handbook for parents with new ...
# 1  mccarthys writing and portrayal of lester ball...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...
#
#                                     Nostopwords_text  \
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...
#
#                                     NoFreqwords_text
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...

# %% [markdown]
# ### 5. Removal of rare words:

# %%
n_rare_words = 10
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])
def remove_rarewords(NoFreqwords_text):
    """custom function to remove the rare words"""
    return " ".join([word for word in str(NoFreqwords_text).split() if word not in RAREWORDS])

df["NoRareFreqwords_text"] = df["NoFreqwords_text"].apply(lambda NoFreqwords_text: remove_rarewords(NoFreqwords_text))
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                       lowercase_text  \
# 0  this all-spanish handbook for parents with new...
# 1  mccarthy's writing and portrayal of lester bal...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...
#
#                                  NoPunctuations_text  \
# 0  this allspanish handbook for parents with new ...
# 1  mccarthys writing and portrayal of lester ball...
# 2  do you giggle uncontrollably when poking corps...
# 3  i was initiated into the world of cormac mccar...
# 4  i cannot speak to the literary points in the n...
#
#                                     Nostopwords_text  \
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...
#
#                                     NoFreqwords_text  \
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...
#
#                                 NoRareFreqwords_text
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...

# %% [markdown]
# ### 6. Stemming:

# %%
from nltk.stem.porter import PorterStemmer

# Drop the four columns 
df.drop(["NoFreqwords_text", "lowercase_text", "NoPunctuations_text","Nostopwords_text"], axis=1, inplace=True) 

stemmer = PorterStemmer()
def stem_words(NoRareFreqwords_text):
    return " ".join([stemmer.stem(word) for word in NoRareFreqwords_text.split()])

df["Stemmed_text"] = df["NoRareFreqwords_text"].apply(lambda NoRareFreqwords_text: stem_words(NoRareFreqwords_text))
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                 NoRareFreqwords_text  \
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...
#
#                                         Stemmed_text
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corps stick look youi und...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...

# %%
  nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\SAMARTH P
# [nltk_data]     SHET\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
def lemmatize_words(Stemmed_text):
    return " ".join([lemmatizer.lemmatize(word) for word in Stemmed_text.split()])

df["Lemmatized_text"] = df["Stemmed_text"].apply(lambda Stemmed_text: lemmatize_words(Stemmed_text))
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                 NoRareFreqwords_text  \
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...
#
#                                         Stemmed_text  \
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corps stick look youi und...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...
#
#                                      Lemmatized_text
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corp stick look youi unde...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...

# %% [markdown]
# ### 7. Removings of URLs, if there are no emojis and emoticons

# %%
# importing regular expression
import re
def remove_urls(Lemmatized_text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', Lemmatized_text)

df["URL_removed_text"] = df["Lemmatized_text"].apply(lambda Lemmatized_text: remove_urls(Lemmatized_text))
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                 NoRareFreqwords_text  \
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...
#
#                                         Stemmed_text  \
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corps stick look youi und...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...
#
#                                      Lemmatized_text  \
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corp stick look youi unde...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...
#
#                                     URL_removed_text
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corp stick look youi unde...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...

# %% [markdown]
# ### 8. Removing of tags:

# %%
def remove_html(URL_removed_text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', URL_removed_text)

df["Tags_Removed_text"] = df["URL_removed_text"].apply(lambda URL_removed_text: remove_html(URL_removed_text))
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                 NoRareFreqwords_text  \
# 0  allspanish handbook parents new babies prove e...
# 1  mccarthys writing portrayal lester ballard nec...
# 2  giggle uncontrollably poking corpses stick loo...
# 3  initiated world cormac mccarthy novel southern...
# 4  cannot speak literary points novel though say ...
#
#                                         Stemmed_text  \
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corps stick look youi und...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...
#
#                                      Lemmatized_text  \
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corp stick look youi unde...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...
#
#                                     URL_removed_text  \
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corp stick look youi unde...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...
#
#                                    Tags_Removed_text
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corp stick look youi unde...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...

# %%
df.drop(["NoRareFreqwords_text", "Stemmed_text", "Lemmatized_text", "URL_removed_text"], axis=1, inplace=True)
df.head()
# Out:
#                                          review_text  \
# 0  This all-Spanish handbook for parents with new...
# 1  McCarthy's writing and portrayal of Lester Bal...
# 2  Do you giggle uncontrollably when poking corps...
# 3  I was initiated into the world of Cormac McCar...
# 4  I cannot speak to the literary points in the n...
#
#                                    Tags_Removed_text
# 0  allspanish handbook parent new babi prove esse...
# 1  mccarthi write portray lester ballard necrophi...
# 2  giggl uncontrol poke corp stick look youi unde...
# 3  initi world cormac mccarthi novel southern lit...
# 4  cannot speak literari point novel though say e...

# %%
from textblob import TextBlob

def getSubjectivity(Tags_Removed_text):
    return TextBlob(Tags_Removed_text).sentiment.subjectivity
    
def getPolarity(Tags_Removed_text):
    return TextBlob(Tags_Removed_text).sentiment.polarity

df ['polarity'] = df['Tags_Removed_text'].apply(getPolarity)
df['subjectivity'] = df['Tags_Removed_text'].apply(getSubjectivity)

def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
df['Analysis_labels'] = df['polarity'].apply(lambda x: getAnalysis(x))

# %%
df
# Out:
#                                              review_text  \
# 0      This all-Spanish handbook for parents with new...
# 1      McCarthy's writing and portrayal of Lester Bal...
# 2      Do you giggle uncontrollably when poking corps...
# 3      I was initiated into the world of Cormac McCar...
# 4      I cannot speak to the literary points in the n...
# ...                                                  ...
# 41995  In reading this book, I traveled on a wonderfu...
# 41996  This wonderful book touches the inner soul.You...
# 41997  I am a 45 year old woman who has been on a que...
# 41998  It is written that you should hide the Word of...
# 41999  John Beckett has the feel of an average guy th...
#
#                                        Tags_Removed_text  polarity  \
# 0      allspanish handbook parent new babi prove esse...  0.096591
# 1      mccarthi write portray lester ballard necrophi... -0.008095
# 2      giggl uncontrol poke corp stick look youi unde...  0.049762
# 3      initi world cormac mccarthi novel southern lit... -0.046591
# 4      cannot speak literari point novel though say e...  0.089226
# ...                                                  ...       ...
# 41995  read travel wonder thought inspir journey reaf...  0.283333
# 41996  wonder touch inner soulyou identifi passag dis...  0.066667
# 41997  45 year old woman quest posit selfmotiv last t... -0.175397
# 41998  written hide word god heart speak live heart o...  0.199650
# 41999  john beckett feel averag guy step help famili ...  0.177500
#
#        subjectivity Analysis_labels
# 0          0.196970        Positive
# 1          0.150952        Negative
# 2          0.289643        Positive
# 3          0.361827        Negative
# 4          0.425926        Positive
# ...             ...             ...
# 41995      0.500000        Positive
# 41996      0.233333        Positive
# 41997      0.475298        Negative
# 41998      0.557692        Positive
# 41999      0.382500        Positive
#
# [42000 rows x 5 columns]

# %% [markdown]
# ## Model Building:

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df['Tags_Removed_text'],
                                                 df['Analysis_labels'],
                                                 test_size = 0.2,random_state = 324)

# %%
X_train.shape
# Out:
# (33600,)

# %%
X_test.shape
# Out:
# (8400,)

# %%
df['Analysis_labels'].value_counts()
# Out:
# Positive    30296
# Negative     8659
# Neutral      3045
# Name: Analysis_labels, dtype: int64

# %% [markdown]
# ### Feature Extraction:

# %% [markdown]
# Here in Feature Extraction, we are using two different methods :
# > `CountVectorizer`
#
# > `TfidfVectorizer`

# %%
# importing the library
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### 1. CountVectorizer

# %%
vect1 = CountVectorizer()
cv_train = vect1.fit_transform(X_train)
cv_test = vect1.transform(X_test)

# %%
print(vect1.vocabulary_)
# Out:
# {'may': 18836, 'particularli': 22335, 'recent': 25020, 'public': 24302, 'deserv': 8286, 'renew': 25395, 'attent': 2758, 'ongo': 21508, 'recommend': 25060, 'light': 17708, 'modern': 19659, 'event': 10466, 'contemporari': 6871, 'concern': 6624, 'jame': 16287, 'walsh': 32977, 'cant': 5069, 'cheat': 5686, 'honest': 14540, 'man': 18466, 'ponzi': 23352, 'scheme': 26568, 'pyramid': 24415, 'fraud': 12073, 'workand': 33882, 'theyr': 30389, 'common': 6447, 'ever': 10483, 'focus': 11728, 'work': 33875, 'avoid': 2937, 'scam': 26518, 'con': 6604, 'name': 20259, 'chang': 5526, 'involv': 15939, 'case': 5239, 'studi': 29111, 'greed': 13171, 'exploit': 10815, 'outlin': 21856, 'investor': 15921, 'learn': 17368, 'woe': 33781, 'taken': 29754, 'relev': 25315, 'today': 30883, '1998': 394, 'start': 28661, 'slow': 27901, 'get': 12651, 'past': 22374, 'first': 11516, 'chapter': 5560, 'wont': 33821, 'abl': 945, 'put': 24406, 'know': 16922, 'anyth': 2209, 'new': 20577, 'york': 34346, 'find': 11457, 'fascin': 11138, 'im': 15076, 'sure': 29481, 'appeal': 2288, 'someon': 28150, 'never': 20566, 'regardless': 25211, 'found': 11983, 'best': 3642, 'sue': 29314, 'grafton': 13067, 'far': 11105, 'extrem': 10889, 'suspens': 29549, 'guess': 13341, 'way': 33122, 'end': 9958, 'murder': 20120, 'surpris': 29505, 'sadden': 26247, 'engross': 10046, 'seri': 27106, 'wait': 32938, 'letter': 17530, 'dont': 9049, 'wal': 32951, 'mart': 18681, 'area': 2420, 'yet': 34315, 'come': 6378, 'soon': 28206, 'pick': 22932, 'curious': 7575, 'seem': 26840, 'everyon': 10507, 'favorit': 11217, 'bash': 3265, 'toy': 31120, 'matter': 18801, 'mani': 18524, 'peopl': 22589, 'author': 2858, 'intrigu': 15854, 'page': 22117, 'onh': 21509, 'give': 12736, 'interest': 15742, 'histori': 14364, 'sam': 26340, 'walton': 32980, 'founder': 11989, 'compani': 6472, 'also': 1765, 'retail': 25606, 'busi': 4828, 'affect': 1345, 'economyn': 9553, 'interject': 15773, 'sarcast': 26410, 'remark': 25357, 'well': 33270, 'insight': 15628, 'keep': 16705, 'reader': 24824, 'toe': 30905, 'throughout': 30629, 'present': 23759, 'fact': 10962, 'ive': 16246, 'year': 34263, 'newspap': 20603, 'tidbit': 30688, 'wouldnt': 34040, 'mediah': 18995, 'make': 18400, 'point': 23237, 'argument': 2455, 'ye': 34258, 'giant': 12684, 'largest': 17199, 'world': 33943, 'pay': 22467, 'employe': 9912, 'fairli': 11006, 'health': 13887, 'insur': 15687, 'high': 14219, 'turnov': 31533, 'move': 19963, 'small': 27920, 'rural': 26182, 'commun': 6456, 'take': 29750, 'away': 2960, 'job': 16430, 'edg': 9576, 'mom': 19699, 'pop': 23379, 'competitor': 6527, 'life': 17640, 'nowaday': 21058, 'lot': 18061, 'cheapwal': 5685, 'took': 30995, 'advantag': 1292, 'suburbia': 29254, 'mania': 18525, 'leav': 17385, 'downtown': 9170, 'suburb': 29251, 'mall': 18447, 'made': 18291, 'price': 23837, 'lower': 18137, 'till': 30708, 'fade': 10986, 'practic': 23572, 'censorship': 5404, 'certain': 5451, 'music': 20147, 'artist': 2557, 'magazin': 18318, 'sell': 26991, 'gun': 13391, 'religi': 25328, 'materi': 18757, 'store': 28878, 'readi': 24861, 'excus': 10652, 'complaint': 6539, 'doesnt': 8946, 'address': 1218, 'issu': 16093, 'handit': 13591, 'definit': 8061, 'waken': 32949, 'go': 12826, 'countri': 7180, 'husband': 14852, 'union': 32014, 'member': 19074, 'final': 11448, 'understand': 31853, 'antiw': 2177, 'institut': 15670, 'guilti': 13369, 'cheap': 5677, 'biggest': 3756, 'easiest': 9479, 'sometim': 28166, 'truth': 31447, 'hurtsif': 14851, 'your': 34391, 'look': 18015, 'entertain': 10122, 'read': 24808, 'think': 30439, 'compel': 6507, 'action': 1145, 'even': 10457, 'simpl': 27644, 'act': 1143, 'shop': 27411, 'anymor': 2197, 'support': 29461, 'local': 17925, 'beach': 3334, 'seriou': 27127, 'situat': 27720, 'face': 10944, 'wish': 33722, 'sooner1290': 28209, 'wonder': 33813, 'reveal': 25648, 'evil': 10534, 'fundmentalist': 12288, 'includ': 15270, 'relig': 25327, 'den': 8180, 'inform': 15472, '900': 867, 'refer': 25159, 'almost': 1719, 'colleg': 6309, 'textbook': 30130, 'cannot': 5064, ...

# %%
cv_train.shape
# Out:
# (33600, 34513)

# %% [markdown]
# ### 2. TfidfVectorizer

# %%
vect2 = TfidfVectorizer()
TF_train = vect2.fit_transform(X_train)
TF_test = vect2.transform(X_test)

# %%
TF_train.shape
# Out:
# (33600, 34513)

# %%
print(vect2.vocabulary_)
# Out:
# {'may': 18836, 'particularli': 22335, 'recent': 25020, 'public': 24302, 'deserv': 8286, 'renew': 25395, 'attent': 2758, 'ongo': 21508, 'recommend': 25060, 'light': 17708, 'modern': 19659, 'event': 10466, 'contemporari': 6871, 'concern': 6624, 'jame': 16287, 'walsh': 32977, 'cant': 5069, 'cheat': 5686, 'honest': 14540, 'man': 18466, 'ponzi': 23352, 'scheme': 26568, 'pyramid': 24415, 'fraud': 12073, 'workand': 33882, 'theyr': 30389, 'common': 6447, 'ever': 10483, 'focus': 11728, 'work': 33875, 'avoid': 2937, 'scam': 26518, 'con': 6604, 'name': 20259, 'chang': 5526, 'involv': 15939, 'case': 5239, 'studi': 29111, 'greed': 13171, 'exploit': 10815, 'outlin': 21856, 'investor': 15921, 'learn': 17368, 'woe': 33781, 'taken': 29754, 'relev': 25315, 'today': 30883, '1998': 394, 'start': 28661, 'slow': 27901, 'get': 12651, 'past': 22374, 'first': 11516, 'chapter': 5560, 'wont': 33821, 'abl': 945, 'put': 24406, 'know': 16922, 'anyth': 2209, 'new': 20577, 'york': 34346, 'find': 11457, 'fascin': 11138, 'im': 15076, 'sure': 29481, 'appeal': 2288, 'someon': 28150, 'never': 20566, 'regardless': 25211, 'found': 11983, 'best': 3642, 'sue': 29314, 'grafton': 13067, 'far': 11105, 'extrem': 10889, 'suspens': 29549, 'guess': 13341, 'way': 33122, 'end': 9958, 'murder': 20120, 'surpris': 29505, 'sadden': 26247, 'engross': 10046, 'seri': 27106, 'wait': 32938, 'letter': 17530, 'dont': 9049, 'wal': 32951, 'mart': 18681, 'area': 2420, 'yet': 34315, 'come': 6378, 'soon': 28206, 'pick': 22932, 'curious': 7575, 'seem': 26840, 'everyon': 10507, 'favorit': 11217, 'bash': 3265, 'toy': 31120, 'matter': 18801, 'mani': 18524, 'peopl': 22589, 'author': 2858, 'intrigu': 15854, 'page': 22117, 'onh': 21509, 'give': 12736, 'interest': 15742, 'histori': 14364, 'sam': 26340, 'walton': 32980, 'founder': 11989, 'compani': 6472, 'also': 1765, 'retail': 25606, 'busi': 4828, 'affect': 1345, 'economyn': 9553, 'interject': 15773, 'sarcast': 26410, 'remark': 25357, 'well': 33270, 'insight': 15628, 'keep': 16705, 'reader': 24824, 'toe': 30905, 'throughout': 30629, 'present': 23759, 'fact': 10962, 'ive': 16246, 'year': 34263, 'newspap': 20603, 'tidbit': 30688, 'wouldnt': 34040, 'mediah': 18995, 'make': 18400, 'point': 23237, 'argument': 2455, 'ye': 34258, 'giant': 12684, 'largest': 17199, 'world': 33943, 'pay': 22467, 'employe': 9912, 'fairli': 11006, 'health': 13887, 'insur': 15687, 'high': 14219, 'turnov': 31533, 'move': 19963, 'small': 27920, 'rural': 26182, 'commun': 6456, 'take': 29750, 'away': 2960, 'job': 16430, 'edg': 9576, 'mom': 19699, 'pop': 23379, 'competitor': 6527, 'life': 17640, 'nowaday': 21058, 'lot': 18061, 'cheapwal': 5685, 'took': 30995, 'advantag': 1292, 'suburbia': 29254, 'mania': 18525, 'leav': 17385, 'downtown': 9170, 'suburb': 29251, 'mall': 18447, 'made': 18291, 'price': 23837, 'lower': 18137, 'till': 30708, 'fade': 10986, 'practic': 23572, 'censorship': 5404, 'certain': 5451, 'music': 20147, 'artist': 2557, 'magazin': 18318, 'sell': 26991, 'gun': 13391, 'religi': 25328, 'materi': 18757, 'store': 28878, 'readi': 24861, 'excus': 10652, 'complaint': 6539, 'doesnt': 8946, 'address': 1218, 'issu': 16093, 'handit': 13591, 'definit': 8061, 'waken': 32949, 'go': 12826, 'countri': 7180, 'husband': 14852, 'union': 32014, 'member': 19074, 'final': 11448, 'understand': 31853, 'antiw': 2177, 'institut': 15670, 'guilti': 13369, 'cheap': 5677, 'biggest': 3756, 'easiest': 9479, 'sometim': 28166, 'truth': 31447, 'hurtsif': 14851, 'your': 34391, 'look': 18015, 'entertain': 10122, 'read': 24808, 'think': 30439, 'compel': 6507, 'action': 1145, 'even': 10457, 'simpl': 27644, 'act': 1143, 'shop': 27411, 'anymor': 2197, 'support': 29461, 'local': 17925, 'beach': 3334, 'seriou': 27127, 'situat': 27720, 'face': 10944, 'wish': 33722, 'sooner1290': 28209, 'wonder': 33813, 'reveal': 25648, 'evil': 10534, 'fundmentalist': 12288, 'includ': 15270, 'relig': 25327, 'den': 8180, 'inform': 15472, '900': 867, 'refer': 25159, 'almost': 1719, 'colleg': 6309, 'textbook': 30130, 'cannot': 5064, ...

# %% [markdown]
# ## KNN Classifier:

# %% [markdown]
# ### KNN Classifier for CountVectorizer:

# %%
#import KNN classifer and fit on the Training dataset
from sklearn.neighbors import KNeighborsClassifier
model1 = KNeighborsClassifier()
model1.fit(cv_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Accuracy score on training dataset
model1.score(cv_train,y_train)
# Out:
# 0.9995535714285714

# %%
# Accuracy on Test dataset
model1.score(cv_test,y_test)
# Out:
# 0.9942857142857143

# %%
# Performing prediction on Test dataset
expected = y_test
predicted = model1.predict(cv_test)

# %%
# plot confusion matrix for the test dataset
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# %%
# Calculating F1 score
from sklearn import metrics
from sklearn.metrics import f1_score
f1_score(expected, predicted, average='macro')
# Out:
# 0.9871397964692025

# %% [markdown]
# ### KNN Classifier for TfidVectorizer:

# %%
model2 = KNeighborsClassifier()
model2.fit(TF_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
# Accuracy score on training dataset
model2.score(TF_train,y_train)
# Out:
# 0.9996726190476191

# %%
# Accuracy on Test dataset
model2.score(TF_test,y_test)
# Out:
# 0.9954761904761905

# %%
# Performing prediction on Test dataset
expected = y_test
predicted = model2.predict(TF_test)

# %%
# plot confusion matrix for the test dataset
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# %%
# Calculating F1 score
from sklearn import metrics
from sklearn.metrics import f1_score
f1_score(expected, predicted, average='macro')
# Out:
# 0.9934321552836466

# %%
import pickle
pickle.dump(model2, open('model2.pkl', 'wb'))
